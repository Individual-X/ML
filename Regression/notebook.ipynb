# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv("E:\Code\python\Deep Learning\data.csv")
dataframe.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
dataframe = dataframe.dropna()

# %%
dataframe = dataframe.fillna(dataframe.mean())

# %%
x=dataframe.iloc[:, 1:2].values
x
# Out:
# array([[110],
#        [117],
#        [103],
#        [109],
#        [117],
#        [102],
#        [110],
#        [104],
#        [109],
#        [ 98],
#        [103],
#        [100],
#        [106],
#        [104],
#        [ 98],
#        [ 98],
#        [100],
#        [103],
#        [ 97],
#        [108],
#        [100],
#        [130],
#        [105],
#        [102],
#        [100],
#        [ 92],
#        [100],
#        [102],
#        [ 92],
#        [ 90],
#        [101],
#        [ 93],
#        [107],
#        [114],
#        [102],
#        [100],
#        [100],
#        [104],
#        [ 90],
#        [ 98],
#        [100],
#        [111],
#        [111],
#        [ 99],
#        [109],
#        [111],
#        [108],
#        [111],
#        [107],
#        [123],
#        [106],
#        [118],
#        [136],
#        [121],
#        [118],
#        [115],
#        [153],
#        [123],
#        [108],
#        [110],
#        [109],
#        [118],
#        [110],
#        [ 90],
#        [105],
#        [107],
#        [106],
#        [108],
#        [ 97],
#        [109],
#        [100],
#        [ 97],
#        [114],
#        [ 98],
#        [105],
#        [110],
#        [100],
#        [100],
#        [159],
#        [149],
#        [103],
#        [100],
#        [100],
#        [151],
#        [102],
#        [100],
#        [129],
#        [ 83],
#        [101],
#        [ 90],
#        [ 80],
#        [150],
#        [151],
#        [ 95],
#        [152],
#        [109],
#        [ 93],
#        [ 95],
#        [ 90],
#        [ 90],
#        [ 90],
#        [ 92],
#        [ 93],
#        [ 90],
#        [ 90],
#        [ 90],
#        [137],
#        [102],
#        [107],
#        [124],
#        [100],
#        [108],
#        [108],
#        [116],
#        [ 97],
#        [103],
#        [112],
#        [100],
#        [119],
#        [107],
#        [111],
#        [ 98],
#        [ 97],
#        [109],
#        [ 99],
#        [114],
#        [104],
#        [107],
#        [103],
#        [106],
#        [103],
#        [136],
#        [117],
#        [115],
#        [113],
#        [141],
#        [108],
#        [100],
#        [122],
#        [136],
#        [106],
#        [107],
#        [112],
#        [103],
#        [110],
#        [106],
#        [109],
#        [109],
#        [150],
#        [105],
#        [111],
#        [ 97],
#        [100],
#        [114],
#        [ 80],
#        [ 85],
#        [ 90],
#        [ 95],
#        [100],
#        [105],
#        [110],
#        [115],
#        [120],
#        [125]], dtype=int64)

# %%
y=dataframe.iloc[:,3:].values
y
# Out:
# array([[ 409.1],
#        [ 479. ],
#        [ 340. ],
#        [ 282.4],
#        [ 406. ],
#        [ 300. ],
#        [ 374. ],
#        [ 253.3],
#        [ 195.1],
#        [ 269. ],
#        [ 329.3],
#        [ 250.7],
#        [ 345.3],
#        [ 379.3],
#        [ 275. ],
#        [ 215.2],
#        [ 300. ],
#        [ 323. ],
#        [ 243. ],
#        [ 364.2],
#        [ 282. ],
#        [ 300. ],
#        [ 246. ],
#        [ 334.5],
#        [ 250. ],
#        [ 241. ],
#        [ 280. ],
#        [ 380.3],
#        [ 243. ],
#        [ 180.1],
#        [ 299. ],
#        [ 223. ],
#        [ 361. ],
#        [ 415. ],
#        [ 300. ],
#        [ 300. ],
#        [ 300. ],
#        [ 266. ],
#        [ 180.1],
#        [ 286. ],
#        [ 329.4],
#        [ 400. ],
#        [ 397. ],
#        [ 273. ],
#        [ 387.6],
#        [ 300. ],
#        [ 298. ],
#        [ 397.6],
#        [ 380.2],
#        [ 643.1],
#        [ 263. ],
#        [ 486. ],
#        [ 238. ],
#        [ 450.7],
#        [ 413. ],
#        [ 305. ],
#        [ 226.4],
#        [ 321. ],
#        [1376. ],
#        [1034.4],
#        [ 853. ],
#        [ 341. ],
#        [ 131.4],
#        [ 800.4],
#        [ 873.4],
#        [ 816. ],
#        [ 110.4],
#        [1500.2],
#        [1115. ],
#        [ 387.6],
#        [ 700. ],
#        [ 953.2],
#        [ 304. ],
#        [ 563.2],
#        [ 251. ],
#        [ 300. ],
#        [ 500.4],
#        [1729. ],
#        [ 319.2],
#        [ 344. ],
#        [ 151.1],
#        [ 500. ],
#        [ 225.3],
#        [ 300. ],
#        [ 234. ],
#        [1000.1],
#        [ 242. ],
#        [  50.3],
#        [ 600.1],
#        [ 105.3],
#        [  50.5],
#        [ 127.4],
#        [ 229.4],
#        [ 128.2],
#        [ 244.2],
#        [ 188.2],
#        [ 604.1],
#        [  77.7],
#        [ 500. ],
#        [ 500. ],
#        [ 500.4],
#        [  92.7],
#        [ 124. ],
#        [ 800.3],
#        [  86.2],
#        [ 500.3],
#        [1860.4],
#        [ 325.2],
#        [ 275. ],
#        [ 124.2],
#        [ 225.3],
#        [ 367.6],
#        [ 351.7],
#        [ 443. ],
#        [ 277.4],
#        [ 332.7],
#        [ 193.9],
#        [ 100.7],
#        [ 336.7],
#        [ 344.9],
#        [ 368.5],
#        [ 271. ],
#        [ 275.3],
#        [ 382. ],
#        [ 466.4],
#        [ 384. ],
#        [ 342.5],
#        [ 357.5],
#        [ 335. ],
#        [ 327.5],
#        [ 339. ],
#        [ 189. ],
#        [ 317.7],
#        [ 318. ],
#        [ 308. ],
#        [ 222.4],
#        [ 390. ],
#        [ 250.4],
#        [ 335.4],
#        [ 470.2],
#        [ 270.8],
#        [ 400. ],
#        [ 361.9],
#        [ 185. ],
#        [ 409.4],
#        [ 343. ],
#        [ 353.2],
#        [ 374. ],
#        [ 275.8],
#        [ 328. ],
#        [ 368.5],
#        [ 270.4],
#        [ 270.4],
#        [ 382.8],
#        [ 240.9],
#        [ 250.4],
#        [ 260.4],
#        [ 270. ],
#        [ 280.9],
#        [ 290.8],
#        [ 300. ],
#        [ 310.2],
#        [ 320.4],
#        [ 330.4]])

# %%
plt.subplot(1, 2, 1)
plt.plot(x)

plt.subplot(1, 2, 2)
plt.plot(y, marker = '')

# %%
plt.plot(y, marker = '')

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predction_x = model.predict(x_test)
predction_y = model.predict(x_train)

# %%
plt.scatter(x_train, y_train, color="green")   
plt.plot(x_train, predction_y, color="red")    
plt.title("Salary vs Experience (Training Dataset)")  
plt.xlabel("Years of Experience")  
plt.ylabel("Salary(In Rupees)")  
plt.show()
